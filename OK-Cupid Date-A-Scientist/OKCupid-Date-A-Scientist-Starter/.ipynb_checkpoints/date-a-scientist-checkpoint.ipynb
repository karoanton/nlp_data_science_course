# %% [markdown]
# # Import data and packages into notebook

# %%
import pandas as pd

# %%
profiles = pd.read_csv('profiles.csv')

# %% [markdown]
# # Load and check dataset

# %%
profiles.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   35         average       mostly other     often  sometimes
# 2   38            thin           anything  socially        NaN
# 3   23            thin         vegetarian  socially        NaN
# 4   29        athletic                NaN  socially      never
#
#                            education  \
# 0      working on college/university
# 1              working on space camp
# 2     graduated from masters program
# 3      working on college/university
# 4  graduated from college/university
#
#                                               essay0  \
# 0  about me:<br />\n<br />\ni would love to think...
# 1  i am a chef: this is what that means.<br />\n1...
# 2  i'm not ashamed of much, but writing public te...
# 3          i work in a library and go to school. . .
# 4  hey how's it going? currently vague on the pro...
#
# ...

# %%
profiles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   body_type    54650 non-null  object
#  2   diet         35551 non-null  object
#  3   drinks       56961 non-null  object
#  4   drugs        45866 non-null  object
#  5   education    53318 non-null  object
#  6   essay0       54458 non-null  object
#  7   essay1       52374 non-null  object
#  8   essay2       50308 non-null  object
#  9   essay3       48470 non-null  object
#  10  essay4       49409 non-null  object
#  11  essay5       49096 non-null  object
#  12  essay6       46175 non-null  object
#  13  essay7       47495 non-null  object
#  14  essay8       40721 non-null  object
#  15  essay9       47343 non-null  object
#  16  ethnicity    54266 non-null  object
#  17  height       59943 non-null  float64
# ...

# %%
profiles.describe()
# Out:
#                 age        height          income
# count  59946.000000  59943.000000    59946.000000
# mean      32.340290     68.295281    20033.222534
# std        9.452779      3.994803    97346.192104
# min       18.000000      1.000000       -1.000000
# 25%       26.000000     66.000000       -1.000000
# 50%       30.000000     68.000000       -1.000000
# 75%       37.000000     71.000000       -1.000000
# max      110.000000     95.000000  1000000.000000

# %% [markdown]
# # Preprocess Data

# %% [markdown]
# For many of the columns in **profiles**, the labels assigned to them make it unclear what information they feature. I will start the preprocessing by changing the names of the following columns:

# %% [markdown]
# - *orientation* will become *sexual_orientation*
# - *sign* will become *astrological_sign*
# - *speaks* will become *languages*
# - *status* will become *marital_status*

# %%
profiles.rename(columns={"orientation": "sexual_orientation", "sign": "astrological_sign", "speaks": "languages", "status": "marital_status"})
# Out:
#        age       body_type               diet      drinks      drugs  \
# 0       22  a little extra  strictly anything    socially      never
# 1       35         average       mostly other       often  sometimes
# 2       38            thin           anything    socially        NaN
# 3       23            thin         vegetarian    socially        NaN
# 4       29        athletic                NaN    socially      never
# ...    ...             ...                ...         ...        ...
# 59941   59             NaN                NaN    socially      never
# 59942   24             fit    mostly anything       often  sometimes
# 59943   42         average    mostly anything  not at all      never
# 59944   27        athletic    mostly anything    socially      often
# 59945   39         average                NaN    socially        NaN
#
#                                education  \
# 0          working on college/university
# 1                  working on space camp
# ...

# %% [markdown]
# A decision tree classification model will be used to predict the diets of the user profiles where that information is missing. Decision trees have the advantage of handling missing values in a dataset well and can be used in problems where instances must be assigned to three or more classes.
#
# To create this decision tree model, I need a data point with the following features:
# - What is the religion of the user?
# - What kind of body type do they have?
# - What is their level of education?

# %% [markdown]
# These four features, along with the *diet* variable, need to undergo cleaning before we conduct any work with them to create the decision tree. Let's begin with the *diet* variable as it is the focus of our question.

# %%
profiles.diet.nunique()
# Out:
# 18

# %%
profiles.diet.unique()
# Out:
# array(['strictly anything', 'mostly other', 'anything', 'vegetarian', nan,
#        'mostly anything', 'mostly vegetarian', 'strictly vegan',
#        'strictly vegetarian', 'mostly vegan', 'strictly other',
#        'mostly halal', 'other', 'vegan', 'mostly kosher',
#        'strictly halal', 'halal', 'strictly kosher', 'kosher'],
#       dtype=object)

# %% [markdown]
# There are 18 unique categories of diet. These diets range from 'anything' to 'vegan' and include diets connected to religious practice like 'kosher' and 'halal'. All of these diets are further broken down by the qualifiers 'strictly' and 'mostly'. This is quite messy and leaves us with several outcomes for the decision tree. To reduce the number of outcomes, these categories will be reduced into each individual diet. For instance, 'mostly vegetarian', 'vegetarian', and 'strictly vegetarian' will be organized into one category, 'vegetarian', and so on.

# %%
profiles['dietsCleaned'] = profiles.diet.str.split().str.get(1)
print(profiles.dietsCleaned.nunique())
print(profiles.dietsCleaned.unique())
# Out:
# 6
# ['anything' 'other' nan 'vegetarian' 'vegan' 'halal' 'kosher']

# %% [markdown]
# Now the number of diets has been reduced to 6 categories.
#
# Let's go ahead and do the same to the four features.

# %%
print(profiles.religion.nunique())
print(profiles.religion.unique())
# Out:
# 45
# ['agnosticism and very serious about it'
#  'agnosticism but not too serious about it' nan 'atheism' 'christianity'
#  'christianity but not too serious about it'
#  'atheism and laughing about it' 'christianity and very serious about it'
#  'other' 'catholicism' 'catholicism but not too serious about it'
#  'catholicism and somewhat serious about it'
#  'agnosticism and somewhat serious about it'
#  'catholicism and laughing about it' 'agnosticism and laughing about it'
#  'agnosticism' 'atheism and somewhat serious about it'
#  'buddhism but not too serious about it'
#  'other but not too serious about it' 'buddhism'
#  'other and laughing about it' 'judaism but not too serious about it'
#  'buddhism and laughing about it' 'other and somewhat serious about it'
#  'other and very serious about it' 'hinduism but not too serious about it'
#  'atheism but not too serious about it' 'judaism'
#  'christianity and somewhat serious about it'
# ...

# %%
profiles['religionCleaned'] = profiles.religion.str.split().str.get(0)
print(profiles.religionCleaned.nunique())
print(profiles.religionCleaned.unique())
# Out:
# 9
# ['agnosticism' nan 'atheism' 'christianity' 'other' 'catholicism'
#  'buddhism' 'judaism' 'hinduism' 'islam']

# %%
print(profiles.body_type.nunique())
print(profiles.body_type.unique())
# Out:
# 12
# ['a little extra' 'average' 'thin' 'athletic' 'fit' nan 'skinny' 'curvy'
#  'full figured' 'jacked' 'rather not say' 'used up' 'overweight']

# %% [markdown]
# *body type* does not need further breaking down so we will leave that feature as is.

# %%
print(profiles.education.nunique())
print(profiles.education.unique())
# Out:
# 32
# ['working on college/university' 'working on space camp'
#  'graduated from masters program' 'graduated from college/university'
#  'working on two-year college' nan 'graduated from high school'
#  'working on masters program' 'graduated from space camp'
#  'college/university' 'dropped out of space camp'
#  'graduated from ph.d program' 'graduated from law school'
#  'working on ph.d program' 'two-year college'
#  'graduated from two-year college' 'working on med school'
#  'dropped out of college/university' 'space camp'
#  'graduated from med school' 'dropped out of high school'
#  'working on high school' 'masters program' 'dropped out of ph.d program'
#  'dropped out of two-year college' 'dropped out of med school'
#  'high school' 'working on law school' 'law school'
#  'dropped out of masters program' 'ph.d program'
#  'dropped out of law school' 'med school']

# %%
education_levels = {'high school': ['graduated from high school', 'dropped out of college/university', 'dropped out of two-year college', 'high school'], 
 'in high school': 'working on high school', 
 'post-secondary': ['graduated from college/university', 'college/university', 'two-year college', 'graduated from two-year college', 
                    'dropped out of med school', 'dropped out of masters program', 'dropped out of law school'], 
 'in post-secondary': ['working on college/university', 'working on two-year college'], 
 'graduate program': ['graduated from masters program', 'graduated from ph.d program', 'graduated from law school', 'graduated from med school', 
                      'masters program', 'dropped out of ph.d program', 'law school', 'ph.d program', 'med school'], 
 'in graduate program': ['working on masters program', 'working on ph.d program', 'working on med school', 'working on law school'], 
 'other': ['graduated from space camp', 'dropped out of space camp', 'space camp', 'dropped out of high school'], 'in other': 'working on space camp'}

# %%
profiles['educationCleaned'] = profiles.education.map(education_levels)
print(profiles.head())
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   35         average       mostly other     often  sometimes
# 2   38            thin           anything  socially        NaN
# 3   23            thin         vegetarian  socially        NaN
# 4   29        athletic                NaN  socially      never
#
#                            education  \
# 0      working on college/university
# 1              working on space camp
# 2     graduated from masters program
# 3      working on college/university
# 4  graduated from college/university
#
#                                               essay0  \
# 0  about me:<br />\n<br />\ni would love to think...
# 1  i am a chef: this is what that means.<br />\n1...
# 2  i'm not ashamed of much, but writing public te...
# 3          i work in a library and go to school. . .
# 4  hey how's it going? currently vague on the pro...
#
# ...
